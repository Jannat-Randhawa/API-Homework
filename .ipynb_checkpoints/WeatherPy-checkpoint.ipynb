# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Set temp units 
temp_units = "imperial"

#Set weather api url 
base_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
print(cities[0])
# Out:
# 637
# kieta

# %%
#Set Query for URL 
query = base_url + cities[0]
query
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=a2be38c9e2a07990378f6221fcbfaf7c&units=imperial&q=kieta'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set variables for the list
city_data = []
country = []
lat = []
lng = []
date = []
humidity = []
cloudiness = []
max_temp = []
wind_speed = []

#Set record and count 
record_count = 0
set_count = 1

#Set Loops and responses.

#print data retreival 
print('''Beginning Data Retrieval     
-----------------------------''')

#Set loop and append responses to the list above. 

for city in cities: 
    
    query = base_url + city 
    response = requests.get(query).json()
    
    try: 
        country.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        date.append(response['dt'])
        cloudiness.append(response['clouds']['all'])
        humidity.append(response['main']['humidity'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        if record_count > 49: 
            record_count = 1 
            set_count += 1
            city_data.append(city) 
            print(f'Processing Record {record_count} of Set {set_count} | {city}')
        else: 
            record_count += 1 
            city_data.append(city)
            print(f'Processing Record {record_count} of Set {set_count} | {city}')

    except Exception: 
        print(f"City not found. Skipping...")
        


print(f'''-----------------------------
Data Retrieval Complete      
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kieta
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | te anau
# Processing Record 5 of Set 1 | biak
# Processing Record 6 of Set 1 | tautira
# City not found. Skipping...
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | guamuchil
# Processing Record 14 of Set 1 | los llanos de aridane
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | kloulklubed
# Processing Record 21 of Set 1 | canto do buriti
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | sembakung
# Processing Record 26 of Set 1 | cortona
# Processing Record 27 of Set 1 | yulara
# Processing Record 28 of Set 1 | kesinga
# Processing Record 29 of Set 1 | canutama
# Processing Record 30 of Set 1 | shenjiamen
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | union
# Processing Record 34 of Set 1 | kampar
# Processing Record 35 of Set 1 | olafsvik
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | constantine
# Processing Record 38 of Set 1 | batagay
# Processing Record 39 of Set 1 | tuatapere
# Processing Record 40 of Set 1 | borba
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | marawi
# Processing Record 43 of Set 1 | bathsheba
# Processing Record 44 of Set 1 | ahipara
# City not found. Skipping...
# Processing Record 45 of Set 1 | pabna
# Processing Record 46 of Set 1 | puerto penasco
# Processing Record 47 of Set 1 | maceio
# Processing Record 48 of Set 1 | san policarpo
# Processing Record 49 of Set 1 | altay
# Processing Record 50 of Set 1 | kantunilkin
# Processing Record 1 of Set 2 | poya
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | kiruna
# City not found. Skipping...
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | severo-kurilsk
# Processing Record 6 of Set 2 | nantucket
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | conde
# Processing Record 11 of Set 2 | ostersund
# Processing Record 12 of Set 2 | luderitz
# Processing Record 13 of Set 2 | bossangoa
# Processing Record 14 of Set 2 | neryungri
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | gwadar
# Processing Record 17 of Set 2 | hrodna
# Processing Record 18 of Set 2 | sur
# Processing Record 19 of Set 2 | bredasdorp
# City not found. Skipping...
# Processing Record 20 of Set 2 | tigzirt
# Processing Record 21 of Set 2 | lorengau
# City not found. Skipping...
# Processing Record 22 of Set 2 | kurchum
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | henties bay
# Processing Record 25 of Set 2 | bilibino
# Processing Record 26 of Set 2 | albany
# Processing Record 27 of Set 2 | puerto carreno
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | verkhoyansk
# Processing Record 33 of Set 2 | ust-maya
# City not found. Skipping...
# Processing Record 34 of Set 2 | kentau
# Processing Record 35 of Set 2 | velikiy ustyug
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | aasiaat
# Processing Record 34 of Set 4 | champerico
# Processing Record 35 of Set 4 | montepuez
# Processing Record 36 of Set 4 | smithers
# Processing Record 37 of Set 4 | presidencia roque saenz pena
# Processing Record 38 of Set 4 | boulsa
# Processing Record 39 of Set 4 | desaguadero
# Processing Record 40 of Set 4 | mporokoso
# Processing Record 41 of Set 4 | marolambo
# Processing Record 42 of Set 4 | mount gambier
# Processing Record 43 of Set 4 | garissa
# Processing Record 44 of Set 4 | praia da vitoria
# Processing Record 45 of Set 4 | shaowu
# Processing Record 46 of Set 4 | evensk
# Processing Record 47 of Set 4 | muros
# Processing Record 48 of Set 4 | lavrentiya
# Processing Record 49 of Set 4 | green river
# Processing Record 50 of Set 4 | yar-sale
# Processing Record 1 of Set 5 | saldanha
# Processing Record 2 of Set 5 | vacaria
# Processing Record 3 of Set 5 | pasni
# Processing Record 4 of Set 5 | hithadhoo
# Processing Record 5 of Set 5 | fare
# Processing Record 6 of Set 5 | aksarka
# Processing Record 7 of Set 5 | jiangkou
# Processing Record 8 of Set 5 | warrington
# Processing Record 9 of Set 5 | cartagena
# Processing Record 10 of Set 5 | great yarmouth
# City not found. Skipping...
# Processing Record 11 of Set 5 | egvekinot
# Processing Record 12 of Set 5 | pabrade
# Processing Record 13 of Set 5 | gushikawa
# Processing Record 14 of Set 5 | esperance
# Processing Record 15 of Set 5 | kargasok
# Processing Record 16 of Set 5 | lynn haven
# Processing Record 17 of Set 5 | sao joao da barra
# Processing Record 18 of Set 5 | panzhihua
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | dillon
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | sept-iles
# Processing Record 24 of Set 5 | uddevalla
# City not found. Skipping...
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | waipawa
# Processing Record 27 of Set 5 | mercedes
# Processing Record 28 of Set 5 | bonavista
# Processing Record 29 of Set 5 | ripanj
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | malatya
# Processing Record 32 of Set 5 | nchelenge
# Processing Record 33 of Set 5 | vestmannaeyjar
# Processing Record 34 of Set 5 | opuwo
# Processing Record 35 of Set 5 | san juan
# Processing Record 36 of Set 5 | carutapera
# Processing Record 37 of Set 5 | udachnyy
# Processing Record 38 of Set 5 | clyde river
# City not found. Skipping...
# Processing Record 39 of Set 5 | williamsport
# Processing Record 40 of Set 5 | kundiawa
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | bodden town
# Processing Record 44 of Set 5 | goderich
# Processing Record 45 of Set 5 | roald
# Processing Record 46 of Set 5 | torit
# Processing Record 47 of Set 5 | abalak
# Processing Record 48 of Set 5 | kavieng
# Processing Record 49 of Set 5 | karoi
# Processing Record 50 of Set 5 | pak phanang
# Processing Record 1 of Set 6 | san ignacio
# Processing Record 2 of Set 6 | dingle
# Processing Record 3 of Set 6 | sungaipenuh
# Processing Record 4 of Set 6 | khuzdar
# Processing Record 5 of Set 6 | maltahohe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 6 | turukhansk
# Processing Record 7 of Set 6 | kovur
# Processing Record 8 of Set 6 | krasnoarmeysk
# Processing Record 9 of Set 6 | sampit
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | tomigusuku
# Processing Record 12 of Set 6 | richards bay
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | sioux lookout
# Processing Record 15 of Set 6 | muisne
# Processing Record 16 of Set 6 | mahibadhoo
# Processing Record 17 of Set 6 | bacolod
# Processing Record 18 of Set 6 | vitim
# City not found. Skipping...
# Processing Record 19 of Set 6 | manggar
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | pangody
# Processing Record 22 of Set 6 | makat
# Processing Record 23 of Set 6 | juan de acosta
# City not found. Skipping...
# Processing Record 24 of Set 6 | anadyr
# Processing Record 25 of Set 6 | beloha
# Processing Record 26 of Set 6 | makakilo city
# Processing Record 27 of Set 6 | coquimbo
# Processing Record 28 of Set 6 | saint-pierre
# Processing Record 29 of Set 6 | coahuayana
# Processing Record 30 of Set 6 | betlitsa
# Processing Record 31 of Set 6 | usevya
# Processing Record 32 of Set 6 | sisimiut
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | salym
# Processing Record 35 of Set 6 | tshane
# Processing Record 36 of Set 6 | tiarei
# City not found. Skipping...
# Processing Record 37 of Set 6 | mahanoro
# Processing Record 38 of Set 6 | lompoc
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | nizwa
# Processing Record 41 of Set 6 | severnyy
# Processing Record 42 of Set 6 | urengoy
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | longido
# Processing Record 45 of Set 6 | myski
# Processing Record 46 of Set 6 | araouane
# Processing Record 47 of Set 6 | ancud
# Processing Record 48 of Set 6 | miyako
# Processing Record 49 of Set 6 | alyangula
# Processing Record 50 of Set 6 | cabo san lucas
# Processing Record 1 of Set 7 | isangel
# Processing Record 2 of Set 7 | kupang
# Processing Record 3 of Set 7 | sayanogorsk
# Processing Record 4 of Set 7 | havre-saint-pierre
# Processing Record 5 of Set 7 | warrnambool
# Processing Record 6 of Set 7 | grootfontein
# Processing Record 7 of Set 7 | mufumbwe
# Processing Record 8 of Set 7 | kenai
# Processing Record 9 of Set 7 | kampong chhnang
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | livingston
# City not found. Skipping...
# Processing Record 12 of Set 7 | borovoy
# Processing Record 13 of Set 7 | khasan
# Processing Record 14 of Set 7 | newton
# Processing Record 15 of Set 7 | kommunisticheskiy
# Processing Record 16 of Set 7 | bowen
# Processing Record 17 of Set 7 | orbetello
# Processing Record 18 of Set 7 | ucluelet
# Processing Record 19 of Set 7 | morondava
# Processing Record 20 of Set 7 | krasnogvardeyets
# Processing Record 21 of Set 7 | mezhdurechensk
# Processing Record 22 of Set 7 | ngunguru
# Processing Record 23 of Set 7 | okha
# Processing Record 24 of Set 7 | dhidhdhoo
# Processing Record 25 of Set 7 | zhigansk
# Processing Record 26 of Set 7 | limbang
# Processing Record 27 of Set 7 | colares
# Processing Record 28 of Set 7 | rimbey
# Processing Record 29 of Set 7 | haapiti
# Processing Record 30 of Set 7 | veraval
# Processing Record 31 of Set 7 | trelew
# Processing Record 32 of Set 7 | tukrah
# Processing Record 33 of Set 7 | jacqueville
# Processing Record 34 of Set 7 | saint-georges
# Processing Record 35 of Set 7 | porto san giorgio
# Processing Record 36 of Set 7 | bajil
# Processing Record 37 of Set 7 | songkhla
# Processing Record 38 of Set 7 | frejus
# Processing Record 39 of Set 7 | morant bay
# Processing Record 40 of Set 7 | talnakh
# Processing Record 41 of Set 7 | matara
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 
# Processing Record 13 of Set 9 | pontal do parana
# Processing Record 14 of Set 9 | hofn
# Processing Record 15 of Set 9 | port hedland
# Processing Record 16 of Set 9 | bobrovytsya
# Processing Record 17 of Set 9 | vanimo
# Processing Record 18 of Set 9 | hambantota
# Processing Record 19 of Set 9 | batagay-alyta
# Processing Record 20 of Set 9 | podborany
# City not found. Skipping...
# Processing Record 21 of Set 9 | novaya zaimka
# Processing Record 22 of Set 9 | geraldton
# Processing Record 23 of Set 9 | cidreira
# Processing Record 24 of Set 9 | narsaq
# Processing Record 25 of Set 9 | nuuk
# Processing Record 26 of Set 9 | leningradskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 9 | san patricio
# Processing Record 28 of Set 9 | keflavik
# City not found. Skipping...
# Processing Record 29 of Set 9 | olga
# Processing Record 30 of Set 9 | taos
# Processing Record 31 of Set 9 | pulandian
# Processing Record 32 of Set 9 | bandarbeyla
# Processing Record 33 of Set 9 | aquidauana
# Processing Record 34 of Set 9 | camana
# Processing Record 35 of Set 9 | selogiri
# Processing Record 36 of Set 9 | ashland
# Processing Record 37 of Set 9 | saint-paul
# Processing Record 38 of Set 9 | craig
# Processing Record 39 of Set 9 | prince rupert
# Processing Record 40 of Set 9 | hamilton
# Processing Record 41 of Set 9 | necochea
# Processing Record 42 of Set 9 | guerrero negro
# Processing Record 43 of Set 9 | labrea
# Processing Record 44 of Set 9 | pergamino
# Processing Record 45 of Set 9 | marystown
# Processing Record 46 of Set 9 | okitipupa
# Processing Record 47 of Set 9 | airai
# Processing Record 48 of Set 9 | sarangani
# Processing Record 49 of Set 9 | camacha
# Processing Record 50 of Set 9 | novyy urengoy
# Processing Record 1 of Set 10 | aloleng
# Processing Record 2 of Set 10 | adrar
# Processing Record 3 of Set 10 | faya
# Processing Record 4 of Set 10 | argentan
# Processing Record 5 of Set 10 | kulhudhuffushi
# Processing Record 6 of Set 10 | tiksi
# Processing Record 7 of Set 10 | ust-koksa
# Processing Record 8 of Set 10 | pisco
# City not found. Skipping...
# Processing Record 9 of Set 10 | limenaria
# Processing Record 10 of Set 10 | norman wells
# Processing Record 11 of Set 10 | kargalinskaya
# Processing Record 12 of Set 10 | kuruman
# Processing Record 13 of Set 10 | canico
# Processing Record 14 of Set 10 | ibra
# Processing Record 15 of Set 10 | wismar
# Processing Record 16 of Set 10 | sorong
# Processing Record 17 of Set 10 | miles city
# Processing Record 18 of Set 10 | corsicana
# Processing Record 19 of Set 10 | loreto
# Processing Record 20 of Set 10 | sao francisco de assis
# Processing Record 21 of Set 10 | southbridge
# Processing Record 22 of Set 10 | waspan
# Processing Record 23 of Set 10 | milton
# City not found. Skipping...
# Processing Record 24 of Set 10 | cody
# Processing Record 25 of Set 10 | dongkan
# Processing Record 26 of Set 10 | aksu
# Processing Record 27 of Set 10 | peniche
# Processing Record 28 of Set 10 | naze
# Processing Record 29 of Set 10 | fairbanks
# Processing Record 30 of Set 10 | pawayan
# Processing Record 31 of Set 10 | katherine
# Processing Record 32 of Set 10 | edd
# Processing Record 33 of Set 10 | simao
# Processing Record 34 of Set 10 | acari
# Processing Record 35 of Set 10 | nome
# City not found. Skipping...
# Processing Record 36 of Set 10 | skagen
# Processing Record 37 of Set 10 | upata
# Processing Record 38 of Set 10 | konin
# Processing Record 39 of Set 10 | nyurba
# Processing Record 40 of Set 10 | matay
# Processing Record 41 of Set 10 | nelson bay
# Processing Record 42 of Set 10 | griffith
# Processing Record 43 of Set 10 | fushun
# Processing Record 44 of Set 10 | rock sound
# Processing Record 45 of Set 10 | ust-ilimsk
# Processing Record 46 of Set 10 | fort nelson
# Processing Record 47 of Set 10 | morgan city
# Processing Record 48 of Set 10 | piacabucu
# Processing Record 49 of Set 10 | flagstaff
# Processing Record 50 of Set 10 | san carlos de bariloche
# Processing Record 1 of Set 11 | mweka
# Processing Record 2 of Set 11 | aykhal
# Processing Record 3 of Set 11 | anori
# Processing Record 4 of Set 11 | tezu
# Processing Record 5 of Set 11 | lac du bonnet
# Processing Record 6 of Set 11 | fortuna
# Processing Record 7 of Set 11 | margate
# Processing Record 8 of Set 11 | uarini
# Processing Record 9 of Set 11 | eureka
# Processing Record 10 of Set 11 | urumqi
# Processing Record 11 of Set 11 | kapit
# Processing Record 12 of Set 11 | srednekolymsk
# Processing Record 13 of Set 11 | bereda
# Processing Record 14 of Set 11 | watrous
# Processing Record 15 of Set 11 | anjiang
# Processing Record 16 of Set 11 | paka
# Processing Record 17 of Set 11 | kruisfontein
# Processing Record 18 of Set 11 | oussouye
# Processing Record 19 of Set 11 | portland
# Processing Record 20 of Set 11 | dawlatabad
# Processing Record 21 of Set 11 | gorontalo
# Processing Record 22 of Set 11 | kayattar
# Processing Record 23 of Set 11 | xam nua
# Processing Record 24 of Set 11 | along
# Processing Record 25 of Set 11 | ternate
# Processing Record 26 of Set 11 | nemuro
# City not found. Skipping...
# Processing Record 27 of Set 11 | tankhoy
# Processing Record 28 of Set 11 | tzaneen
# Processing Record 29 of Set 11 | talara
# Processing Record 30 of Set 11 | borogontsy
# City not found. Skipping...
# Processing Record 31 of Set 11 | ayame
# Processing Record 32 of Set 11 | mosalsk
# Processing Record 33 of Set 11 | soyo
# Processing Record 34 of Set 11 | malchin
# Processing Record 35 of Set 11 | kijang
# Processing Record 36 of Set 11 | kazachinskoye
# Processing Record 37 of Set 11 | costa rica
# Processing Record 38 of Set 11 | hay river
# Processing Record 39 of Set 11 | avanigadda
# Processing Record 40 of Set 11 | hanko
# Processing Record 41 of Set 11 | grindavik
# Processing Record 42 of Set 11 | charleston
# Processing Record 43 of Set 11 | komsomolskiy
# Processing Record 44 of Set 11 | guiong
# Processing Record 45 of Set 11 | volga
# Processing Record 46 of Set 11 | gunnedah
# City not found. Skipping...
# Processing Record 47 of Set 11 | tawau
# Processing Record 48 of Set 11 | port keats
# Processing Record 49 of Set 11 | sabang
# Processing Record 50 of Set 11 | gornopravdinsk
# Processing Record 1 of Set 12 | hibbing
# Processing Record 2 of Set 12 | malinovoye ozero
# Processing Record 3 of Set 12 | rio gallegos
# Processing Record 4 of Set 12 | agadir
# Processing Record 5 of Set 12 | bosaso
# Processing Record 6 of Set 12 | mangan
# Processing Record 7 of Set 12 | whitehorse
# Processing Record 8 of Set 12 | hovd
# Processing Record 9 of Set 12 | laguna
# Processing Record 10 of Set 12 | qaqortoq
# Processing Record 11 of Set 12 | tselinnoye
# Processing Record 12 of Set 12 | shahr-e babak
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 12 | cooma
# Processing Record 14 of Set 12 | north platte
# Processing Record 15 of Set 12 | kosa
# Processing Record 16 of Set 12 | tutoia
# Processing Record 17 of Set 12 | plouzane
# Processing Record 18 of Set 12 | tayu
# City not found. Skipping...
# Processing Record 19 of Set 12 | bouna
# Processing Record 20 of Set 12 | kalamare
# Processing Record 21 of Set 12 | jacareacanga
# Processing Record 22 of Set 12 | varhaug
# Processing Record 23 of Set 12 | sao domingos
# Processing Record 24 of Set 12 | bendigo
# Processing Record 25 of Set 12 | bandiagara
# Processing Record 26 of Set 12 | la cruz
# Processing Record 27 of Set 12 | trencin
# Processing Record 28 of Set 12 | toamasina
# Processing Record 29 of Set 12 | luganville
# Processing Record 30 of Set 12 | mexico
# Processing Record 31 of Set 12 | olinda
# Processing Record 32 of Set 12 | kimbe
# City not found. Skipping...
# Processing Record 33 of Set 12 | kjollefjord
# Processing Record 34 of Set 12 | kattivakkam
# Processing Record 35 of Set 12 | englewood
# Processing Record 36 of Set 12 | gopalpur
# Processing Record 37 of Set 12 | porbandar
# Processing Record 38 of Set 12 | la ronge
# Processing Record 39 of Set 12 | mossendjo
# Processing Record 40 of Set 12 | vaitape
# Processing Record 41 of Set 12 | redcar
# Processing Record 42 of Set 12 | tangkak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Covert into dataframe
weather_data = pd.DataFrame({"City": city_data, 
                            "Country": country,
                             "Lat": lat, 
                             "Lng": lng,
                             "Date": date,
                             "Max Temp": max_temp, 
                             "Cloudiness": cloudiness, 
                             "Wind Speed": wind_speed,
                             "Humidity": humidity
                            })
weather_data.count()

#Save dataframe
weather_data.to_csv("output_data/cities.csv", index=False, header=True)

# %%
# Display data in data frame
weather_data.head()
# Out:
#          City Country    Lat     Lng        Date  Max Temp  Cloudiness  \
# 0       kieta      PG  -6.22  155.63  1597107989     85.14          91
# 1       bluff      NZ -46.60  168.33  1597107989     52.00          91
# 2  georgetown      MY   5.41  100.34  1597107989     84.20          20
# 3     te anau      NZ -45.42  167.72  1597107989     47.79          18
# 4        biak      ID  -0.91  122.88  1597107990     81.37          48
#
#    Wind Speed  Humidity
# 0        1.86        63
# 1       14.00        73
# 2        2.24        88
# 3        5.73        68
# 4        4.99        75

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Set date and time 
named_tuple = time.localtime() 
time_string = time.strftime("%m/%d/%Y, %H:%M:%S", named_tuple)

#Plt the scatter graph. 
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Max Temperature {time_string}')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Set date and time 
named_tuple = time.localtime() 
time_string = time.strftime("%m/%d/%Y, %H:%M:%S", named_tuple)

#Plt the scatter graph. 
plt.scatter(weather_data["Lat"], weather_data["Humidity"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Humidity {time_string}')
plt.xlabel('Humidity')
plt.ylabel('Max Temperature (F)')
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Plt the scatter graph. 
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Cloudiness {time_string}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
# Out:
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Wind Speed {time_string}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

#Define the linear regression function 
def plot_linear_regression(x_values, y_values, title, text_coordinates): 
    
    #Run linear regression 
    (slope, intercept, rvalue, pvalue, stderr)= linregress(x_values, y_values)
    regress_values = x_values * slope + intercept 
    line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    #Plot the scatter plot.
    plt.scatter(x_values, y_values)
    
    #Plot the regression line. 
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
    #Label plot 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    #Print r-square value 
    print(f"R squard: {rvalue}")
    
    #Show plot 
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_data.loc[(weather_data["Lat"]>= 0)]
southern_hemisphere = weather_data.loc[(weather_data["Lat"]< 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the regression for Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']

plot_linear_regression(x_values, y_values, 'Max Temp(F)', (6,30))
# Out:
# R squard: -0.7735830149948486

# %% [markdown]
# ##### As displayed on the graph and the high r value there is a strong negative correlation between Max Temp and Latitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot regression Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# Set x and y coordinates
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']

plot_linear_regression(x_values, y_values, 'Max Temp(F)', (-28,42))
# Out:
# R squard: 0.6656425487856491

# %% [markdown]
# ##### As displayed on the graph and the high r value there is a mediocre positive correlation between Max Temp and Latitude in the southern hemisphere.
#
# ##### Overall, there is a strong correlation interms of Max Temp and the hemispheres

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']

plot_linear_regression(x_values, y_values, 'Humidity', (50,16))
# Out:
# R squard: 0.17561995511512069

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']

plot_linear_regression(x_values, y_values, 'Humidity', (-50,22))
# Out:
# R squard: 0.13864245631413796

# %% [markdown]
# ###### As evident on the graph and in the r value the correlation is negligent interms of humidity and both southern and northern hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']

plot_linear_regression(x_values, y_values, 'Cloudiness', (50,30))
# Out:
# R squard: 0.12643970077654912

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']

plot_linear_regression(x_values, y_values, 'Cloudiness', (-50,62))
# Out:
# R squard: 0.19544985566139791

# %% [markdown]
# ###### As evident on the graph and in the r value the correlation is negligent interms of cloudiness and both southern and northern hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']

plot_linear_regression(x_values, y_values, 'Wind Speed', (25,25))
# Out:
# R squard: 0.13650973929041754

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']

plot_linear_regression(x_values, y_values, 'Wind Speed', (-40,18))
# Out:
# R squard: -0.19512105771449328

# %% [markdown]
# ###### As evident on the graph and in the r value the correlation is negligent interms of wind speed and both southern and northern hemispheres.
