# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Set temp units 
temp_units = "imperial"

#Set weather api url 
base_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={temp_units}&q="

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
print(cities[0])
# Out:
# 609
# illoqqortoormiut

# %%
#Set Query for URL 
query = base_url + cities[0]
query
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=a2be38c9e2a07990378f6221fcbfaf7c&units=imperial&q=mataura'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Set variables for the list
city_data = []
country = []
lat = []
lng = []
date = []
humidity = []
cloudiness = []
max_temp = []
wind_speed = []

#Set record and count 
record_count = 0
set_count = 1

#Set Loops and responses.

#print data retreival 
print('''Beginning Data Retrieval     
-----------------------------''')

#Set loop and append responses to the list above. 

for city in cities: 
    
    query = base_url + city 
    response = requests.get(query).json()
    
    try: 
        country.append(response['sys']['country'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        date.append(response['dt'])
        cloudiness.append(response['clouds']['all'])
        humidity.append(response['main']['humidity'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        if record_count > 49: 
            record_count = 1 
            set_count += 1
            city_data.append(city) 
            print(f'Processing Record {record_count} of Set {set_count} | {city}')
        else: 
            record_count += 1 
            city_data.append(city)
            print(f'Processing Record {record_count} of Set {set_count} | {city}')

    except Exception: 
        print(f"City not found. Skipping...")
        


print(f'''-----------------------------
Data Retrieval Complete      
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | vyartsilya
# Processing Record 7 of Set 1 | ashford
# City not found. Skipping...
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | pizarro
# Processing Record 13 of Set 1 | okato
# City not found. Skipping...
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | innisfail
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | sidney
# Processing Record 19 of Set 1 | porto novo
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | katsuura
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | labuhan
# Processing Record 31 of Set 1 | lagoa
# Processing Record 32 of Set 1 | hami
# City not found. Skipping...
# Processing Record 33 of Set 1 | zarate
# Processing Record 34 of Set 1 | yar-sale
# Processing Record 35 of Set 1 | taltal
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | ewo
# Processing Record 38 of Set 1 | lagunas
# Processing Record 39 of Set 1 | mount isa
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | bangangte
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | karasjok
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | mehran
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | santander
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | dharmadam
# Processing Record 1 of Set 2 | birao
# Processing Record 2 of Set 2 | pak phanang
# Processing Record 3 of Set 2 | qui nhon
# Processing Record 4 of Set 2 | mwene-ditu
# Processing Record 5 of Set 2 | hofn
# Processing Record 6 of Set 2 | ughelli
# Processing Record 7 of Set 2 | vardo
# Processing Record 8 of Set 2 | antofagasta
# Processing Record 9 of Set 2 | najran
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | noumea
# City not found. Skipping...
# Processing Record 12 of Set 2 | vila velha
# Processing Record 13 of Set 2 | shimoda
# Processing Record 14 of Set 2 | vao
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | roma
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | pervomayskoye
# Processing Record 20 of Set 2 | mehamn
# Processing Record 21 of Set 2 | ahipara
# Processing Record 22 of Set 2 | huaiyin
# Processing Record 23 of Set 2 | deloraine
# Processing Record 24 of Set 2 | hobart
# Processing Record 25 of Set 2 | tarauaca
# Processing Record 26 of Set 2 | nemuro
# City not found. Skipping...
# Processing Record 27 of Set 2 | beyneu
# Processing Record 28 of Set 2 | port elizabeth
# City not found. Skipping...
# Processing Record 29 of Set 2 | faya
# Processing Record 30 of Set 2 | tortoli
# Processing Record 31 of Set 2 | cherskiy
# Processing Record 32 of Set 2 | bereda
# Processing Record 33 of Set 2 | salinopolis
# Processing Record 34 of Set 2 | hirado
# Processing Record 35 of Set 2 | caucaia
# Processing Record 36 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 37 of Set 2 | lodja
# Processing Record 38 of Set 2 | buala
# Processing Record 39 of Set 2 | namibe
# City not found. Skipping...
# Processing Record 40 of Set 2 | culiacan
# Processing Record 41 of Set 2 | turayf
# Processing Record 42 of Set 2 | leh
# Processing Record 43 of Set 2 | daru
# Processing Record 44 of Set 2 | yanam
# Processing Record 45 of Set 2 | brae
# Processing Record 46 of Set 2 | thompson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 5 | pevek
# City not found. Skipping...
# Processing Record 8 of Set 5 | sterling
# Processing Record 9 of Set 5 | seguela
# Processing Record 10 of Set 5 | leningradskiy
# Processing Record 11 of Set 5 | tombouctou
# Processing Record 12 of Set 5 | safonovo
# Processing Record 13 of Set 5 | molepolole
# Processing Record 14 of Set 5 | talnakh
# Processing Record 15 of Set 5 | samarai
# Processing Record 16 of Set 5 | la libertad
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | kongolo
# Processing Record 19 of Set 5 | sturgeon bay
# Processing Record 20 of Set 5 | behbahan
# Processing Record 21 of Set 5 | biak
# Processing Record 22 of Set 5 | berlevag
# Processing Record 23 of Set 5 | fulton
# Processing Record 24 of Set 5 | vestmanna
# Processing Record 25 of Set 5 | solkan
# Processing Record 26 of Set 5 | jadu
# Processing Record 27 of Set 5 | rio grande
# Processing Record 28 of Set 5 | tynda
# Processing Record 29 of Set 5 | iglesias
# Processing Record 30 of Set 5 | igarka
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | san andres
# Processing Record 33 of Set 5 | pahrump
# Processing Record 34 of Set 5 | meulaboh
# Processing Record 35 of Set 5 | ugoofaaru
# Processing Record 36 of Set 5 | ustka
# Processing Record 37 of Set 5 | westport
# Processing Record 38 of Set 5 | mitsamiouli
# Processing Record 39 of Set 5 | korla
# Processing Record 40 of Set 5 | chama
# Processing Record 41 of Set 5 | uray
# City not found. Skipping...
# Processing Record 42 of Set 5 | caririacu
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | kihei
# Processing Record 45 of Set 5 | kaeo
# Processing Record 46 of Set 5 | bubaque
# City not found. Skipping...
# Processing Record 47 of Set 5 | shalya
# Processing Record 48 of Set 5 | tucuman
# Processing Record 49 of Set 5 | notse
# Processing Record 50 of Set 5 | kirakira
# Processing Record 1 of Set 6 | saint anthony
# Processing Record 2 of Set 6 | aras
# Processing Record 3 of Set 6 | mukhen
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | albertville
# Processing Record 6 of Set 6 | taoudenni
# Processing Record 7 of Set 6 | at-bashi
# Processing Record 8 of Set 6 | hasaki
# Processing Record 9 of Set 6 | makakilo city
# Processing Record 10 of Set 6 | pangnirtung
# Processing Record 11 of Set 6 | terney
# Processing Record 12 of Set 6 | guayaramerin
# Processing Record 13 of Set 6 | illapel
# Processing Record 14 of Set 6 | beloha
# Processing Record 15 of Set 6 | mahibadhoo
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | thinadhoo
# Processing Record 18 of Set 6 | aswan
# Processing Record 19 of Set 6 | laguna
# Processing Record 20 of Set 6 | alofi
# City not found. Skipping...
# Processing Record 21 of Set 6 | saint-joseph
# Processing Record 22 of Set 6 | kifri
# Processing Record 23 of Set 6 | mahebourg
# City not found. Skipping...
# Processing Record 24 of Set 6 | macapa
# Processing Record 25 of Set 6 | yarovoye
# Processing Record 26 of Set 6 | lishu
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | fiumicino
# Processing Record 30 of Set 6 | shulan
# Processing Record 31 of Set 6 | gardanne
# Processing Record 32 of Set 6 | muros
# Processing Record 33 of Set 6 | maarianhamina
# Processing Record 34 of Set 6 | urumqi
# Processing Record 35 of Set 6 | purranque
# Processing Record 36 of Set 6 | karagaylinskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | ponta delgada
# City not found. Skipping...
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | ust-maya
# Processing Record 40 of Set 6 | kasongo-lunda
# Processing Record 41 of Set 6 | poum
# Processing Record 42 of Set 6 | zorritos
# Processing Record 43 of Set 6 | lavrentiya
# Processing Record 44 of Set 6 | mo i rana
# Processing Record 45 of Set 6 | fortuna
# Processing Record 46 of Set 6 | palana
# Processing Record 47 of Set 6 | flin flon
# Processing Record 48 of Set 6 | ambilobe
# City not found. Skipping...
# Processing Record 49 of Set 6 | igrim
# Processing Record 50 of Set 6 | kapchorwa
# Processing Record 1 of Set 7 | misawa
# Processing Record 2 of Set 7 | coruripe
# Processing Record 3 of Set 7 | vestmannaeyjar
# Processing Record 4 of Set 7 | atar
# Processing Record 5 of Set 7 | byron bay
# Processing Record 6 of Set 7 | altay
# Processing Record 7 of Set 7 | beringovskiy
# Processing Record 8 of Set 7 | guiglo
# Processing Record 9 of Set 7 | nizhniy baskunchak
# Processing Record 10 of Set 7 | beirut
# Processing Record 11 of Set 7 | seminole
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | northam
# Processing Record 14 of Set 7 | alice springs
# Processing Record 15 of Set 7 | tabou
# Processing Record 16 of Set 7 | bilma
# Processing Record 17 of Set 7 | lundazi
# Processing Record 18 of Set 7 | tiarei
# Processing Record 19 of Set 7 | mount gambier
# Processing Record 20 of Set 7 | vaasa
# Processing Record 21 of Set 7 | chengzihe
# City not found. Skipping...
# Processing Record 22 of Set 7 | nyurba
# Processing Record 23 of Set 7 | dicabisagan
# Processing Record 24 of Set 7 | morros
# Processing Record 25 of Set 7 | ransang
# Processing Record 26 of Set 7 | chepo
# Processing Record 27 of Set 7 | kolokani
# Processing Record 28 of Set 7 | coahuayana
# Processing Record 29 of Set 7 | san bernardo
# Processing Record 30 of Set 7 | maldonado
# Processing Record 31 of Set 7 | richards bay
# City not found. Skipping...
# Processing Record 32 of Set 7 | gumdag
# Processing Record 33 of Set 7 | xining
# Processing Record 34 of Set 7 | maravatio
# Processing Record 35 of Set 7 | dudinka
# Processing Record 36 of Set 7 | miracema do tocantins
# Processing Record 37 of Set 7 | buchanan
# Processing Record 38 of Set 7 | mishan
# Processing Record 39 of Set 7 | mglin
# Processing Record 40 of Set 7 | moscow
# Processing Record 41 of Set 7 | port blair
# Processing Record 42 of Set 7 | ayan
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | klyuchi
# Processing Record 45 of Set 7 | conde
# Processing Record 46 of Set 7 | kafue
# Processing Record 47 of Set 7 | bucak
# Processing Record 48 of Set 7 | bethel
# Processing Record 49 of Set 7 | yerkoy
# Processing Record 50 of Set 7 | acari
# Processing Record 1 of Set 8 | kaitangata
# Processing Record 2 of Set 8 | oga
# Processing Record 3 of Set 8 | mashhad
# Processing Record 4 of Set 8 | galle
# Processing Record 5 of Set 8 | ngunut
# Processing Record 6 of Set 8 | balabac
# Processing Record 7 of Set 8 | saint-pierre
# Processing Record 8 of Set 8 | krasnoyarsk
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 
# Processing Record 40 of Set 9 | tongliao
# Processing Record 41 of Set 9 | comodoro rivadavia
# Processing Record 42 of Set 9 | kandrian
# Processing Record 43 of Set 9 | gonbad-e qabus
# Processing Record 44 of Set 9 | pacific grove
# Processing Record 45 of Set 9 | lerwick
# Processing Record 46 of Set 9 | bad salzungen
# Processing Record 47 of Set 9 | kapit
# Processing Record 48 of Set 9 | kurilsk
# Processing Record 49 of Set 9 | college
# Processing Record 50 of Set 9 | riyadh
# Processing Record 1 of Set 10 | royan
# Processing Record 2 of Set 10 | savannah bight
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | naze
# Processing Record 5 of Set 10 | tangi
# Processing Record 6 of Set 10 | taber
# Processing Record 7 of Set 10 | dauriya
# Processing Record 8 of Set 10 | rapar
# Processing Record 9 of Set 10 | micheweni
# Processing Record 10 of Set 10 | gondar
# Processing Record 11 of Set 10 | sept-iles
# Processing Record 12 of Set 10 | vanimo
# Processing Record 13 of Set 10 | zhezkazgan
# Processing Record 14 of Set 10 | dunedin
# City not found. Skipping...
# Processing Record 15 of Set 10 | ballina
# City not found. Skipping...
# Processing Record 16 of Set 10 | herat
# Processing Record 17 of Set 10 | havoysund
# Processing Record 18 of Set 10 | lazaro cardenas
# Processing Record 19 of Set 10 | roald
# Processing Record 20 of Set 10 | gisborne
# Processing Record 21 of Set 10 | marsa matruh
# Processing Record 22 of Set 10 | nyuksenitsa
# Processing Record 23 of Set 10 | ust-tsilma
# Processing Record 24 of Set 10 | clearlake
# Processing Record 25 of Set 10 | gannan
# Processing Record 26 of Set 10 | parole
# Processing Record 27 of Set 10 | krutinka
# Processing Record 28 of Set 10 | mae sai
# Processing Record 29 of Set 10 | lamin
# Processing Record 30 of Set 10 | casper
# Processing Record 31 of Set 10 | tangua
# Processing Record 32 of Set 10 | safaga
# Processing Record 33 of Set 10 | okhotsk
# Processing Record 34 of Set 10 | khasan
# Processing Record 35 of Set 10 | nishihara
# Processing Record 36 of Set 10 | tres de maio
# Processing Record 37 of Set 10 | sao joao da barra
# Processing Record 38 of Set 10 | lompoc
# Processing Record 39 of Set 10 | altamira
# Processing Record 40 of Set 10 | jinxiang
# Processing Record 41 of Set 10 | port hardy
# Processing Record 42 of Set 10 | amapa
# Processing Record 43 of Set 10 | san juan
# Processing Record 44 of Set 10 | camacha
# Processing Record 45 of Set 10 | perth
# Processing Record 46 of Set 10 | wajima
# City not found. Skipping...
# Processing Record 47 of Set 10 | oktyabrskiy
# Processing Record 48 of Set 10 | coihaique
# Processing Record 49 of Set 10 | tres arroyos
# Processing Record 50 of Set 10 | amlame
# Processing Record 1 of Set 11 | puerto escondido
# Processing Record 2 of Set 11 | polevskoy
# Processing Record 3 of Set 11 | summerville
# Processing Record 4 of Set 11 | sinnamary
# Processing Record 5 of Set 11 | victoria
# Processing Record 6 of Set 11 | bayan
# Processing Record 7 of Set 11 | mezen
# Processing Record 8 of Set 11 | rumoi
# Processing Record 9 of Set 11 | manitouwadge
# Processing Record 10 of Set 11 | bonavista
# Processing Record 11 of Set 11 | porgera
# Processing Record 12 of Set 11 | nouakchott
# Processing Record 13 of Set 11 | kwinana
# Processing Record 14 of Set 11 | west wendover
# Processing Record 15 of Set 11 | nuuk
# Processing Record 16 of Set 11 | onguday
# Processing Record 17 of Set 11 | waipawa
# Processing Record 18 of Set 11 | vilhena
# Processing Record 19 of Set 11 | akyab
# Processing Record 20 of Set 11 | aitape
# Processing Record 21 of Set 11 | ongandjera
# Processing Record 22 of Set 11 | solok
# Processing Record 23 of Set 11 | nelson bay
# Processing Record 24 of Set 11 | san onofre
# City not found. Skipping...
# Processing Record 25 of Set 11 | brownsburg
# Processing Record 26 of Set 11 | date
# Processing Record 27 of Set 11 | ulaangom
# City not found. Skipping...
# Processing Record 28 of Set 11 | zhengjiatun
# Processing Record 29 of Set 11 | halifax
# Processing Record 30 of Set 11 | fuling
# Processing Record 31 of Set 11 | chernyshevskiy
# Processing Record 32 of Set 11 | santa maria
# Processing Record 33 of Set 11 | kahului
# City not found. Skipping...
# Processing Record 34 of Set 11 | russell
# Processing Record 35 of Set 11 | naryan-mar
# Processing Record 36 of Set 11 | pingyi
# Processing Record 37 of Set 11 | mandera
# City not found. Skipping...
# Processing Record 38 of Set 11 | manggar
# Processing Record 39 of Set 11 | talakan
# Processing Record 40 of Set 11 | brotas
# Processing Record 41 of Set 11 | caraballeda
# Processing Record 42 of Set 11 | benguela
# Processing Record 43 of Set 11 | ahuimanu
# Processing Record 44 of Set 11 | gat
# Processing Record 45 of Set 11 | keetmanshoop
# Processing Record 46 of Set 11 | valley
# Processing Record 47 of Set 11 | tuatapere
# Processing Record 48 of Set 11 | chapada dos guimaraes
# Processing Record 49 of Set 11 | suifenhe
# Processing Record 50 of Set 11 | axim
# Processing Record 1 of Set 12 | nalut
# Processing Record 2 of Set 12 | christchurch
# Processing Record 3 of Set 12 | auki
# Processing Record 4 of Set 12 | kondinskoye
# Processing Record 5 of Set 12 | hamilton
# Processing Record 6 of Set 12 | shache
# Processing Record 7 of Set 12 | manaure
# Processing Record 8 of Set 12 | manaquiri
# Processing Record 9 of Set 12 | chumikan
# Processing Record 10 of Set 12 | mayumba
# Processing Record 11 of Set 12 | duluth
# Processing Record 12 of Set 12 | waterloo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Covert into dataframe
weather_data = pd.DataFrame({"City": city_data, 
                            "Country": country,
                             "Lat": lat, 
                             "Lng": lng,
                             "Date": date,
                             "Max Temp": max_temp, 
                             "Cloudiness": cloudiness, 
                             "Wind Speed": wind_speed,
                             "Humidity": humidity
                            })
weather_data.count()

#Save dataframe
weather_data.to_csv("output_data/cities.csv", index=False, header=True)

# %%
# Display data in data frame
weather_data.head()
# Out:
#            City Country    Lat     Lng        Date  Max Temp  Cloudiness  \
# 0    georgetown      MY   5.41  100.34  1587876955     89.60          20
# 1       rikitea      PF -23.12 -134.97  1587877079     76.01           0
# 2  punta arenas      CL -53.15  -70.92  1587876867     30.20           0
# 3     jamestown      US  42.10  -79.24  1587876993     51.80          90
# 4       mataura      NZ -46.19  168.86  1587877079     61.00          95
#
#    Wind Speed  Humidity
# 0        2.24        79
# 1       17.31        76
# 2        3.36        80
# 3       10.29        87
# 4       13.00        57

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Set date and time 
named_tuple = time.localtime() 
time_string = time.strftime("%m/%d/%Y, %H:%M:%S", named_tuple)

#Plt the scatter graph. 
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Max Temperature {time_string}')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Set date and time 
named_tuple = time.localtime() 
time_string = time.strftime("%m/%d/%Y, %H:%M:%S", named_tuple)

#Plt the scatter graph. 
plt.scatter(weather_data["Lat"], weather_data["Humidity"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Humidity {time_string}')
plt.xlabel('Humidity')
plt.ylabel('Max Temperature (F)')
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Plt the scatter graph. 
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Cloudiness {time_string}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
# Out:
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], alpha=0.8, marker='o', 
           edgecolor="black")
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)
plt.title(f'City Latitude vs. Wind Speed {time_string}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
# Out:
# Text(0, 0.5, 'Wind Speed')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

#Define the linear regression function 
def plot_linear_regression(x_values, y_values, title, text_coordinates): 
    
    #Run linear regression 
    (slope, intercept, rvalue, pvalue, stderr)= linregress(x_values, y_values)
    regress_values = x_values * slope + intercept 
    line_eq = "y=" + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    #Plot the scatter plot.
    plt.scatter(x_values, y_values)
    
    #Plot the regression line. 
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
    #Label plot 
    plt.xlabel("Latitude")
    plt.ylabel(title)
    
    #Print r-square value 
    print(f"R squard: {rvalue}")
    
    #Show plot 
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_data.loc[(weather_data["Lat"]>= 0)]
southern_hemisphere = weather_data.loc[(weather_data["Lat"]< 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot the regression for Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']

plot_linear_regression(x_values, y_values, 'Max Temp(F)', (6,30))
# Out:
# R squard: -0.8771717242192903

# %% [markdown]
# ##### As displayed on the graph and the high r value there is a strong negative correlation between Max Temp and Latitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot regression Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# Set x and y coordinates
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']

plot_linear_regression(x_values, y_values, 'Max Temp(F)', (-28,42))
# Out:
# R squard: 0.6656425487856491

# %% [markdown]
# ##### As displayed on the graph and the high r value there is a mediocre positive correlation between Max Temp and Latitude in the southern hemisphere.
#
# ##### Overall, there is a strong correlation interms of Max Temp and the hemispheres

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']

plot_linear_regression(x_values, y_values, 'Humidity', (50,16))
# Out:
# R squard: 0.17561995511512069

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']

plot_linear_regression(x_values, y_values, 'Humidity', (-50,22))
# Out:
# R squard: 0.13864245631413796

# %% [markdown]
# ###### As evident on the graph and in the r value the correlation is negligent interms of humidity and both southern and northern hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']

plot_linear_regression(x_values, y_values, 'Cloudiness', (50,30))
# Out:
# R squard: 0.12643970077654912

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']

plot_linear_regression(x_values, y_values, 'Cloudiness', (-50,62))
# Out:
# R squard: 0.19544985566139791

# %% [markdown]
# ###### As evident on the graph and in the r value the correlation is negligent interms of cloudiness and both southern and northern hemispheres.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Set x and y coordinates
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']

plot_linear_regression(x_values, y_values, 'Wind Speed', (25,25))
# Out:
# R squard: 0.13650973929041754

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']

plot_linear_regression(x_values, y_values, 'Wind Speed', (-40,18))
# Out:
# R squard: -0.19512105771449328

# %% [markdown]
# ###### As evident on the graph and in the r value the correlation is negligent interms of wind speed and both southern and northern hemispheres.
